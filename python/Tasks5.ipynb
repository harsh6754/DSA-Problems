# %%
import pandas as pd
import matplotlib.pyplot as plt

# Sample data
data = {
    'Category': ['A', 'A', 'B', 'B', 'B', 'C', 'C', 'C', 'C'],
    'Values': [10, 20, 15, 25, 35, 40, 50, 60, 70]
}
df = pd.DataFrame(data)

# Custom aggregation function: Calculate the range (max - min)
def calculate_range(series):
    return series.max() - series.min()

# Group by 'Category' and apply the custom aggregation
result = df.groupby('Category')['Values'].agg(calculate_range)

# Create a visual representation for the report
fig, ax = plt.subplots(figsize=(8, 5))
result.plot(kind='bar', color='skyblue', ax=ax)
ax.set_title("Custom Aggregation: Range by Category", fontsize=14)
ax.set_xlabel("Category", fontsize=12)
ax.set_ylabel("Range (Max - Min)", fontsize=12)
ax.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_excel("C:\\Users\\agarw\\Downloads\\Data.csv.xlsx")
df.head()
# Out:
#        Label  Value  X Values  Y Values
# 0      Apple     10        10         1
# 1     Banana     15        20         5
# 2     Orange      7        30         7
# 3     Grapes     12        40         3
# 4  Pineapple     13        50         6

# %%
x_axis = df['X Values']
y_axis = df['Y Values']

# %%
plt.bar(x_axis,y_axis,width=5)
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
df = pd.read_excel("C:\\Users\\agarw\\Downloads\\Data.csv.xlsx")
plt.pie(df['Value'],labels=df['Label'])
plt.show()
